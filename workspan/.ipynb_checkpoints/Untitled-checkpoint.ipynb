# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set()

df = pd.read_csv('URL_STATUS_REPORThttpsodataintelcom.csv')


df.columns = ['time', 'status','response_time']
df.time = pd.to_datetime(df.time)
df.set_index('time', inplace=True)
df.plot(figsize=(20,10), linewidth=5, fontsize=20)
plt.xlabel('DateTime', fontsize=20);
plt.ylabel('URLStatusAndResponse', fontsize=20);
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-aa17a4207f5a> in <module>
#       6 sns.set()
#       7
# ----> 8 df = pd.read_csv('URL_STATUS_REPORThttpsodataintelcom.csv.csv')
#       9
#      10
#
# ~/workspan/env3.7/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# ~/workspan/env3.7/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# ~/workspan/env3.7/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# ~/workspan/env3.7/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# ~/workspan/env3.7/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File URL_STATUS_REPORThttpsodataintelcom.csv.csv does not exist: 'URL_STATUS_REPORThttpsodataintelcom.csv.csv'

# %%
df.columns = ['time', 'status','response_time']
df.time = pd.to_datetime(df.time)

# %%
df.set_index('time', inplace=True)

# %%
df.head()
# Out:
#                             status  response_time
# time
# 2020-04-27 20:37:11.716762       0              0
# 2020-04-27 20:37:11.742543       0              0
# 2020-04-27 20:37:11.754603       0              0
# 2020-04-27 20:37:11.733367       0              0
# 2020-04-27 20:37:11.709319       0              0

# %%
df.plot(figsize=(20,10), linewidth=5, fontsize=20)
plt.xlabel('DateTime', fontsize=20);
plt.ylabel('UrlStatus', fontsize=20);
